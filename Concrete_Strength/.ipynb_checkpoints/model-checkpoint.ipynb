# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook

# %% [markdown]
# # Data Prep

# %%
# Data Prep
data = pd.read_csv('concrete_data.csv')
data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Cement              1030 non-null   float64
#  1   Blast Furnace Slag  1030 non-null   float64
#  2   Fly Ash             1030 non-null   float64
#  3   Water               1030 non-null   float64
#  4   Superplasticizer    1030 non-null   float64
#  5   Coarse Aggregate    1030 non-null   float64
#  6   Fine Aggregate      1030 non-null   float64
#  7   Age                 1030 non-null   int64
#  8   Strength            1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %%
sns.heatmap(data.corr(), annot=True)
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# <AxesSubplot:>

# %%
features = data.drop(columns=['Strength'])
target = data[['Strength']]

# %%
# Feature Selection
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestRegressor
estimator = RandomForestRegressor()
selector = RFE(estimator)
selector.fit(features, target)
# Out:
# D:\@happy.ai.ml\devDL\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# D:\@happy.ai.ml\devDL\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# D:\@happy.ai.ml\devDL\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# ...

# %%
selector.ranking_, selector.feature_names_in_
# Out:
# (array([1, 1, 5, 1, 2, 4, 3, 1]),
#  array(['Cement', 'Blast Furnace Slag', 'Fly Ash', 'Water',
#         'Superplasticizer', 'Coarse Aggregate', 'Fine Aggregate', 'Age'],
#        dtype=object))

# %%
selected_features = data[['Cement', 'Blast Furnace Slag', 'Water', 'Age']]

# %% [markdown]
# # Modeling

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.7.0'

# %%
class Model:

    def __init__(self,
                 input_dim=1,
                 epochs: int = 10,
                 learning_rate: float = 0.01):
        self.epochs = epochs
        self.learning_rate = learning_rate
        # weights and bias random initialization
        self.weights = tf.Variable(tf.random.uniform((input_dim, ), seed=42),
                                   name='weights')
        self.bias = tf.Variable(1.0, name='bias')
        # Cost Function
        self.compute_loss = lambda ypred, ytrue: tf.reduce_mean(
            tf.square(ypred - ytrue))
        # forward propagation
        self.forward = lambda x: self.weights * x + self.bias

    #train model
    def train(self, x, ytrue):
        for epoch in range(self.epochs):
            with tf.GradientTape() as tape:
                ypred = self.forward(x)
                loss = self.compute_loss(ypred, ytrue)
                #compute gradient
                gradients = tape.gradient(loss, {
                    'weights': self.weights,
                    'bias': self.bias
                })
                self.weights.assign_sub(gradients['weights'] *
                                        self.learning_rate)
                self.bias.assign_sub(gradients['bias'] * self.learning_rate)
                print(f'Loss: {loss}')

# %%
m = Model(input_dim=8, epochs=5)
m.train(features, target)
# Out:
# Loss: 157694.234375
# Loss: 684595937280.0
# Loss: 3.428042509673038e+18
# Loss: 1.8396070867739071e+25
# Loss: 1.0189660482957301e+32

# %%
m.forward(features.values[0])
# Out:
# <tf.Tensor: shape=(8,), dtype=float32, numpy=
# array([-1.8660571e+14, -7.9423626e+13, -7.9423626e+13, -8.2049478e+13,
#        -7.9425001e+13, -7.1856032e+19, -4.6816512e+18, -7.9537870e+13],
#       dtype=float32)>
